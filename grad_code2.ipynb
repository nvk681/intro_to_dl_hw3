# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from torchvision.datasets import CIFAR10
import os
import torch
# To read zipped .tar, .tz file
import tarfile
from torchvision.datasets.utils import download_url
from torchvision.datasets import ImageFolder
from torchvision.transforms import ToTensor
import torchvision.transforms as transforms
# Below library will help us to pass batch of data, as feeding all data at once will lead to OverLoading and System will get Hang
from torch.utils.data.dataloader import DataLoader
# These libraries will help us to plot images
import matplotlib.pyplot as plt
from torchvision.utils import make_grid
# Out:
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")

# %% [markdown]
# In computer-vision, CIFAR-10  is an established benchmark dataset used object recognition. It is a subset of 80 million tiny images. CIFAR-10 consists of $60,000$ $32\times32$ color images containing objects of one of 10 classes (with 6000 images per class). It was collected by Alex Krizhevsky, Vinod Nair, and Geoffrey Hinton.
#
# The classes represented in the dataset are:
#
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck

# %% [markdown]
# # Import Required Libraries and Load Data from Pytorch Dataset

# %% [markdown]
# Download the data from URL below

# %%
# url = 'https://s3.amazonaws.com/fast-ai-imageclas/cifar10.tgz'
# download_url(url, '.')

# %%
# with tarfile.open('./cifar10.tgz', 'r:gz') as tar:
#     tar.extractall(path = './data')

# %% [markdown]
# Data is now in the `./data` folder

# %%
data_dir = './data/cifar10'
print(os.listdir(data_dir))

classes = os.listdir(data_dir + '/train')
print(classes)
# Out:
# ['test', 'train']
# ['cat', 'dog', 'truck', 'bird', 'airplane', 'ship', 'frog', 'horse', 'deer', 'automobile']

# %% [markdown]
# As displayed, we have 10 Classes, and 2 folders are available Train and Test

# %% [markdown]
# Let's read some of images and plot them

# %%
airplane_file = os.listdir(data_dir + '/train/airplane')
print('Number of Training Examples: ', len(airplane_file))
print(airplane_file[:5])
# Out:
# Number of Training Examples:  5000
# ['3975.png', '1804.png', '4968.png', '1810.png', '3961.png']

# %%
ship_file = os.listdir(data_dir + '/test/ship')
print('Number of Testing Examples: ', len(ship_file))
print(ship_file[:5])
# Out:
# Number of Testing Examples:  1000
# ['0298.png', '0267.png', '0501.png', '0515.png', '0273.png']

# %% [markdown]
# ### Image Augumentation
# - We have to do this job before making our model. The expectation that augmentation will prevent overfitting. This is not guaranteed and at the current stage in the class where we have not covered the topic is a dirty hack. Please treat it as such. namely - an artificial way to increase training data without relying on the unknown data generation process.
#
# To additionally reduce the chance of overfitting, let's carry out Normalization and Regularization as below

# %%
trans = transforms.Compose(
    [   
        transforms.Resize(256),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize([0.49139968, 0.48215841, 0.44653091], [0.24703223 , 0.24348513, 0.26158784])
    ]
)

# %% [markdown]
# Let's load train and test data

# %%
train_ds = ImageFolder(data_dir+'/train', transform = trans)
val_ds = ImageFolder(data_dir+'/test', transform = trans)

# %% [markdown]
# # Hyperparameters
#
# ##  Add more parameters for your code.

# %%
# this is one of Hyper parameter, add more parameters for your code.
batch_size = 512

# %%
# PyTorch data loaders
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)
valid_dl = DataLoader(val_ds, batch_size*2, num_workers=3, pin_memory=True)

# %% [markdown]
# # Plot and observe sets

# %%
def show_batch(dl):
    for images, labels in dl:
        fig, ax = plt.subplots(figsize = (12,12))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(images[: 100], 10).permute(1,2,0))
        break

# %%
show_batch(train_dl)
# Out:
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
show_batch(valid_dl)
# Out:
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# We can see some changes in images from original image from dataset

# %%
img, label = train_ds[0]
img.shape, label
# Out:
# (torch.Size([3, 256, 256]), 0)

# %% [markdown]
# # Model Building:
# ### follow the same process we did for MNIST in Colab notebooks

# %% [markdown]
# These libraries will help us to build Neural Network

# %%
import torch.nn as nn
import torch.nn.functional as F

# %% [markdown]
# # Implement AlexNet architecture: https://proceedings.neurips.cc/paper/2012/file/c399862d3b9d6b76c8436e924a68c45b-Paper.pdf

# %%
class AlexNet(nn.Module):
    
    def __init__(self, num_classes):
        
        super().__init__()
        
        self.net = nn.Sequential(
            nn.Conv2d(in_channels=3, out_channels=96, kernel_size=11, stride=4),
            nn.ReLU(),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(96, 256, 5, padding=2),
            nn.ReLU(),
            nn.LocalResponseNorm(size=5, alpha=0.0001, beta=0.75, k=2),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(256, 384, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(384, 384, 3, padding=1),
            nn.ReLU(),
            nn.Conv2d(384, 256, 3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=3, stride=2),
            nn.Conv2d(256, 256, kernel_size = 3, padding = 1),
            nn.ReLU(inplace = True),
            nn.MaxPool2d(kernel_size = 3, stride = 2)
        )

        self.avgpool = nn.AdaptiveAvgPool2d((6,6))

        self.classifier = nn.Sequential(
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(in_features=(256 * 6 * 6), out_features=4096),
            nn.ReLU(),
            nn.Dropout(p=0.5, inplace=True),
            nn.Linear(in_features=4096, out_features=4096),
            nn.ReLU(),
            nn.Linear(in_features=4096, out_features=num_classes),
        )
        self.init_bias() 

    def init_bias(self):
        for layer in self.net:
            if isinstance(layer, nn.Conv2d):
                nn.init.normal_(layer.weight, mean=0, std=0.01)
                nn.init.constant_(layer.bias, 0)
        nn.init.constant_(self.net[4].bias, 1)
        nn.init.constant_(self.net[10].bias, 1)
        nn.init.constant_(self.net[12].bias, 1)


    def forward(self, x):
        x = self.net(x)
        x = self.avgpool(x)
        x = x.view(-1, 256 * 6 * 6)
        return self.classifier(x)

# %%
# lets Initialize Model
model = AlexNet(num_classes = 10)

# %%
# to get all details of Model
model
# Out:
# AlexNet(
#   (net): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU()
#     (2): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (5): ReLU()
#     (6): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU(inplace=True)
#     (17): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=True)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=True)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# Let's Verify Models

# %%
sample = next(iter(train_ds))
img = sample[0]
img.shape
# Out:
# torch.Size([3, 256, 256])

# %%
out = model(img.unsqueeze(0))

# %%
 # Demo plot

for images, labels in train_dl:
    print('Image Shape', images.shape)
    out = model(images)
    print('output shape', out.shape)
    print('out[0]', out[0])
    break
# Out:
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# Image Shape torch.Size([512, 3, 256, 256])
# output shape torch.Size([512, 10])
# out[0] tensor([-0.0333, -0.1527,  0.0821, -0.0879,  0.0020, -0.0388,  0.0564,  0.0651,
#          0.0034,  0.0491], grad_fn=<SelectBackward0>)

# %% [markdown]
# So, model has initial guess, it seems all options have been given same weightage i.e. 10%

# %%
probs = F.softmax(out[0], dim = 0)
probs
# Out:
# tensor([0.0970, 0.0861, 0.1089, 0.0919, 0.1005, 0.0965, 0.1061, 0.1070, 0.1006,
#         0.1053], grad_fn=<SoftmaxBackward0>)

# %%
plt.imshow(img.permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# # Device Selection

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
train_dl = DeviceDataLoader(train_dl, device)
val_dl = DeviceDataLoader(valid_dl, device)
to_device(model, device)
# Out:
# AlexNet(
#   (net): Sequential(
#     (0): Conv2d(3, 96, kernel_size=(11, 11), stride=(4, 4))
#     (1): ReLU()
#     (2): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (4): Conv2d(96, 256, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#     (5): ReLU()
#     (6): LocalResponseNorm(5, alpha=0.0001, beta=0.75, k=2)
#     (7): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (8): Conv2d(256, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (9): ReLU()
#     (10): Conv2d(384, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (11): ReLU()
#     (12): Conv2d(384, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (13): ReLU()
#     (14): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (15): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (16): ReLU(inplace=True)
#     (17): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(6, 6))
#   (classifier): Sequential(
#     (0): Dropout(p=0.5, inplace=True)
#     (1): Linear(in_features=9216, out_features=4096, bias=True)
#     (2): ReLU()
#     (3): Dropout(p=0.5, inplace=True)
#     (4): Linear(in_features=4096, out_features=4096, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# # Define Helper Functions

# %%
def loss_batch(model, loss_func, x, y, opt = None, metric = None):
    metric_result = None

    pred = model(x)#[model(img) for img in x]######## ADD YOUR MODEL HERE ########
    
    loss = loss_func(pred, y)######## ADD YOUR LOSS FUNCTION HERE ########
    
    if opt is not None:
        # scores = model(x)
        # loss = loss_func(scores, y)
        loss.backward()
        opt.zero_grad()
        optimizer.step()
    
    if metric is not None:
        metric_result = metric(pred, y)
        
    return loss.item(), len(x), metric_result

# %% [markdown]
# # Add your evaluation function here
#
# 1. Add loss_batch with x and y in list results
# 2. calcualte the average loss by using losses and nums of samples
# 3. calculate the average metrics by using metrics and nums of samples

# %%
def evaluate(model, loss_fn, val_dl, metric = None):
    with torch.no_grad():
        # for image, lable in val_dl:
        results = [loss_batch(model, loss_fn, x, y, metric = metric) for x, y in val_dl]        
        losses, nums, metrics = zip(*results)
        avg_metric = None
        total = np.sum(nums)
        avg_loss = np.sum(np.multiply(losses , nums))/total #np.sum(losses,nums)/total #None###### ADD YOUR CODE HERE ########        
        
        if metric is not None:
            # pass
            avg_metric = np.sum(np.multiply(metrics,nums))/total###### ADD YOUR CODE HERE ########
            
    return avg_loss, total, avg_metric

# %% [markdown]
# We have defined Scheduler to handle Learning rate, as with SGD, we would be looking for Learning rate that changes based on Accuracy
# If Model finds no change in Accuracy, it will reduce learning rate by factor of 0.1. Controling parameter would be validation accuracy.

# %%
def fit(epochs, model, loss_fn, train_dl, val_dl, opt_fn = None, metric = None, scheduler = None, scheduler_on = 'val_metric'):
    train_losses, val_losses, val_metrics = [], [], []
    model.train()
    for x, y in train_dl:
        train_loss, _, _ = loss_batch(model, loss_fn, x, y, opt_fn)
        model.eval()
        result = evaluate(model, loss_fn, val_dl, metric)
        val_loss, total, val_metric = result
        train_losses.append(val_loss)
        val_losses.append(total)
        val_metrics.append(val_metric)
        print("Total: ", "To")

            
    return train_losses, val_losses, val_metrics

# %% [markdown]
# Function to find accuracy, as there is no built in function in Pytorh to find accuracy, its simple code to define accuracy as below

# %%
def accuracy(output, labels):
    _, preds = torch.max(output, dim = 1)
    
    return torch.sum(preds == labels).item() / len(preds)

# %% [markdown]
# Lets verify initial guess on validation

# %%
loss_fn = torch.nn.functional.cross_entropy#(output, target_var) ######## ADD YOUR CODE HERE ########
# val_loss, _, val_acc = evaluate(model, loss_fn, val_dl, metric = accuracy)

# print(val_loss, val_acc)

# %% [markdown]
# # Train Model

# %%
num_epochs = 90######## ADD YOUR CODE HERE ########

optimizer =  torch.optim.Adam(params = model.parameters(), lr=0.0001)######## ADD YOUR CODE HERE ########
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, factor = 0.1, mode = 'max', verbose = True)

# %%
history = fit(1, model, loss_fn, train_dl, val_dl, optimizer, accuracy, scheduler, 'val_metric')
print(history)
# Out:
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# /Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torchvision/io/image.py:11: UserWarning: Failed to load image Python extension:
#   warn(f"Failed to load image Python extension: {e}")
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /Users/venkatakrishnachaitanyanuthalapati/University/Into to Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb Cell 5' in <module>
# ----> <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000004?line=0'>1</a> history = fit(1, model, loss_fn, train_dl, val_dl, optimizer, accuracy, scheduler, 'val_metric')
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000004?line=1'>2</a> print(history)
#
# /Users/venkatakrishnachaitanyanuthalapati/University/Into to Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb Cell 53' in fit(epochs, model, loss_fn, train_dl, val_dl, opt_fn, metric, scheduler, scheduler_on)
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000052?line=2'>3</a> model.train()
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000052?line=3'>4</a> for x, y in train_dl:
# ----> <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000052?line=4'>5</a>     train_loss, _, _ = loss_batch(model, loss_fn, x, y, opt_fn)
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000052?line=5'>6</a>     model.eval()
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000052?line=6'>7</a>     result = evaluate(model, loss_fn, val_dl, metric)
#
# /Users/venkatakrishnachaitanyanuthalapati/University/Into to Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb Cell 49' in loss_batch(model, loss_func, x, y, opt, metric)
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000048?line=5'>6</a> loss = loss_func(pred, y)######## ADD YOUR LOSS FUNCTION HERE ########
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000048?line=7'>8</a> if opt is not None:
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000048?line=8'>9</a>     # scores = model(x)
#      <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000048?line=9'>10</a>     # loss = loss_func(scores, y)
# ---> <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000048?line=10'>11</a>     loss.backward()
#      <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000048?line=11'>12</a>     opt.zero_grad()
#      <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000048?line=12'>13</a>     optimizer.step()
#
# File ~/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py:307, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py?line=297'>298</a> if has_torch_function_unary(self):
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py?line=298'>299</a>     return handle_torch_function(
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py?line=299'>300</a>         Tensor.backward,
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py?line=300'>301</a>         (self,),
#    (...)
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py?line=304'>305</a>         create_graph=create_graph,
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py?line=305'>306</a>         inputs=inputs)
# --> <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/_tensor.py?line=306'>307</a> torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#
# File ~/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py:154, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py?line=150'>151</a> if retain_graph is None:
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py?line=151'>152</a>     retain_graph = create_graph
# --> <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py?line=153'>154</a> Variable._execution_engine.run_backward(
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py?line=154'>155</a>     tensors, grad_tensors_, retain_graph, create_graph, inputs,
#     <a href='file:///Users/venkatakrishnachaitanyanuthalapati/Library/Python/3.8/lib/python/site-packages/torch/autograd/__init__.py?line=155'>156</a>     allow_unreachable=True, accumulate_grad=True)
#
# RuntimeError: one of the variables needed for gradient computation has been modified by an inplace operation: [torch.FloatTensor [512, 4096]], which is output 0 of ReluBackward0, is at version 1; expected version 0 instead. Hint: enable anomaly detection to find the operation that failed to compute its gradient, with torch.autograd.set_detect_anomaly(True).

# %% [markdown]
# Accuracy of AlexNet model on validation set is:

# %% [markdown]
# # BONUS: PRE-TRAINING USING ResNet
#
# use the following code: `from torchvision import datasets, models, transforms`
#
# TASK:
# 1. Finetune the model using ResNet
# 2. Load the pretrained model and reset a final fully connected layer
# 3. Train and evaluate
#
# It should take around 15-25 min on CPU. On GPU though, it takes less than a minute.

# %% [markdown]
# # Plotting result

# %% [markdown]
# Plotting Train Losses

# %%
plt.figure(figsize = (8,8))
plt.plot(history[0], '-x')
plt.xlabel('Epochs')
plt.ylabel('Training Loss')
plt.title('Plot between Training Loss vs Epochs')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/venkatakrishnachaitanyanuthalapati/University/Into to Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb Cell 1' in <module>
# ----> <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000000?line=0'>1</a> plt.figure(figsize = (8,8))
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000000?line=1'>2</a> plt.plot(history[0], '-x')
#       <a href='vscode-notebook-cell:/Users/venkatakrishnachaitanyanuthalapati/University/Into%20to%20Deep/Assignment-3/CODE_PROBLEM/grad_code/grad_code2.ipynb#ch0000000?line=2'>3</a> plt.xlabel('Epochs')
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize = (8,8))
plt.plot(history[2], '-x')
plt.xlabel('Epochs')
plt.ylabel('Validation Loss')
plt.title('Plot between Validation Loss vs Epochs')
# Out:
# Text(0.5, 1.0, 'Plot between Validation Loss vs Epochs')
